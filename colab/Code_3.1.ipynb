# %% [markdown]
# # 三重積と四重積の証明

# %% [markdown]
# 吉田勝俊（宇都宮大学）

# %% [markdown]
# ## 参考情報
# - [SymPyで代数演算してみる - Qiita](https://qiita.com/zawawahoge/items/1be137a8147902a5e6cb)
# - [Matrices (linear algebra) &#8212; SymPy 1.6.2 documentation](https://docs.sympy.org/latest/modules/matrices/matrices.html)

# %%
import sympy as sym #数式処理ライブラリ
sym.init_printing() #数式を綺麗に表示する設定

# %% [markdown]
# ## Sympy 変数・関数

# %%
x1, x2, x3 = sym.symbols('x_1 x_2 x_3')
y1, y2, y3 = sym.symbols('y_1 y_2 y_3')
z1, z2, z3 = sym.symbols('z_1 z_2 z_3')

xs = sym.Matrix([x1,x2,x3]) #xベクトル
ys = sym.Matrix([y1,y2,y3]) #yベクトル
zs = sym.Matrix([z1,z2,z3]) #zベクトル

xs, ys, zs
# Out:
# ⎛⎡x₁⎤  ⎡y₁⎤  ⎡z₁⎤⎞
# ⎜⎢  ⎥  ⎢  ⎥  ⎢  ⎥⎟
# ⎜⎢x₂⎥, ⎢y₂⎥, ⎢z₂⎥⎟
# ⎜⎢  ⎥  ⎢  ⎥  ⎢  ⎥⎟
# ⎝⎣x₃⎦  ⎣y₃⎦  ⎣z₃⎦⎠

# %%
#判定用のゼロベクトル
zeros = sym.Matrix([0,0,0])

zeros
# Out:
# ⎡0⎤
# ⎢ ⎥
# ⎢0⎥
# ⎢ ⎥
# ⎣0⎦

# %% [markdown]
# #### 外積と内積のテスト

# %%
xs.cross(ys) #外積
# Out:
# ⎡x₂⋅y₃ - x₃⋅y₂ ⎤
# ⎢              ⎥
# ⎢-x₁⋅y₃ + x₃⋅y₁⎥
# ⎢              ⎥
# ⎣x₁⋅y₂ - x₂⋅y₁ ⎦

# %%
xs.dot(ys) #内積
# Out:
# x₁⋅y₁ + x₂⋅y₂ + x₃⋅y₃

# %% [markdown]
# ## (O4) スカラ三重積

# %%
left  = xs.dot(ys.cross(zs)) #左辺の式
right = xs.cross(ys).dot(zs) #右辺の式
difference = left-right #差をとる
difference = sym.simplify(difference) #式を整理する

print('Left =')
display(left)

print('Right =')
display(right)

print('Difference =')
display(difference)

#判定結果
if difference == 0:
  print('==> "O4" is True.')
# Out:
# Left =
# x₁⋅(y₂⋅z₃ - y₃⋅z₂) + x₂⋅(-y₁⋅z₃ + y₃⋅z₁) + x₃⋅(y₁⋅z₂ - y₂⋅z₁)
# Right =
# z₁⋅(x₂⋅y₃ - x₃⋅y₂) + z₂⋅(-x₁⋅y₃ + x₃⋅y₁) + z₃⋅(x₁⋅y₂ - x₂⋅y₁)
# Difference =
# 0
# ==> "O4" is True.

# %% [markdown]
# ## (O5) ベクトル四重積

# %%
left  = xs.cross(ys.cross(zs)) #左辺の式
right = xs.dot(zs)*ys - xs.dot(ys)*zs #右辺の式
difference = left-right #差をとる
difference = sym.simplify(difference) #式を整理する

print('Left =')
display(left)

print('Right =')
display(right)

print('Difference =')
display(difference)

#判定結果
if difference == zeros: #上で定義したゼロベクトル
  print('==>"O5" is True.')
# Out:
# Left =
# ⎡x₂⋅(y₁⋅z₂ - y₂⋅z₁) - x₃⋅(-y₁⋅z₃ + y₃⋅z₁)⎤
# ⎢                                        ⎥
# ⎢-x₁⋅(y₁⋅z₂ - y₂⋅z₁) + x₃⋅(y₂⋅z₃ - y₃⋅z₂)⎥
# ⎢                                        ⎥
# ⎣x₁⋅(-y₁⋅z₃ + y₃⋅z₁) - x₂⋅(y₂⋅z₃ - y₃⋅z₂)⎦
# Right =
# ⎡y₁⋅(x₁⋅z₁ + x₂⋅z₂ + x₃⋅z₃) - z₁⋅(x₁⋅y₁ + x₂⋅y₂ + x₃⋅y₃)⎤
# ⎢                                                       ⎥
# ⎢y₂⋅(x₁⋅z₁ + x₂⋅z₂ + x₃⋅z₃) - z₂⋅(x₁⋅y₁ + x₂⋅y₂ + x₃⋅y₃)⎥
# ⎢                                                       ⎥
# ⎣y₃⋅(x₁⋅z₁ + x₂⋅z₂ + x₃⋅z₃) - z₃⋅(x₁⋅y₁ + x₂⋅y₂ + x₃⋅y₃)⎦
# Difference =
# ⎡0⎤
# ⎢ ⎥
# ⎢0⎥
# ⎢ ⎥
# ⎣0⎦
# ==>"O5" is True.

# %% [markdown]
# ## (O6) 名無しの四重積

# %%
left  = xs.cross(ys.cross(xs.cross(ys))) #左辺の式
right = ys.cross(xs.cross(xs.cross(ys))) #右辺の式
difference = left-right #差をとる
difference = sym.simplify(difference) #式を整理する

print('Left =')
display(left)

print('Right =')
display(right)

print('Difference =')
display(difference)

#判定結果
if difference == zeros: #上で定義したゼロベクトル
  print('==> "O6" is True.')
# Out:
# Left =
# ⎡x₂⋅(y₁⋅(-x₁⋅y₃ + x₃⋅y₁) - y₂⋅(x₂⋅y₃ - x₃⋅y₂)) - x₃⋅(-y₁⋅(x₁⋅y₂ - x₂⋅y₁) + y₃⋅
# ⎢
# ⎢-x₁⋅(y₁⋅(-x₁⋅y₃ + x₃⋅y₁) - y₂⋅(x₂⋅y₃ - x₃⋅y₂)) + x₃⋅(y₂⋅(x₁⋅y₂ - x₂⋅y₁) - y₃⋅
# ⎢
# ⎣x₁⋅(-y₁⋅(x₁⋅y₂ - x₂⋅y₁) + y₃⋅(x₂⋅y₃ - x₃⋅y₂)) - x₂⋅(y₂⋅(x₁⋅y₂ - x₂⋅y₁) - y₃⋅(
#
# (x₂⋅y₃ - x₃⋅y₂)) ⎤
#                  ⎥
# (-x₁⋅y₃ + x₃⋅y₁))⎥
#                  ⎥
# -x₁⋅y₃ + x₃⋅y₁)) ⎦
# Right =
# ⎡y₂⋅(x₁⋅(-x₁⋅y₃ + x₃⋅y₁) - x₂⋅(x₂⋅y₃ - x₃⋅y₂)) - y₃⋅(-x₁⋅(x₁⋅y₂ - x₂⋅y₁) + x₃⋅
# ⎢
# ⎢-y₁⋅(x₁⋅(-x₁⋅y₃ + x₃⋅y₁) - x₂⋅(x₂⋅y₃ - x₃⋅y₂)) + y₃⋅(x₂⋅(x₁⋅y₂ - x₂⋅y₁) - x₃⋅
# ⎢
# ⎣y₁⋅(-x₁⋅(x₁⋅y₂ - x₂⋅y₁) + x₃⋅(x₂⋅y₃ - x₃⋅y₂)) - y₂⋅(x₂⋅(x₁⋅y₂ - x₂⋅y₁) - x₃⋅(
#
# (x₂⋅y₃ - x₃⋅y₂)) ⎤
#                  ⎥
# (-x₁⋅y₃ + x₃⋅y₁))⎥
#                  ⎥
# -x₁⋅y₃ + x₃⋅y₁)) ⎦
# Difference =
# ⎡0⎤
# ⎢ ⎥
# ⎢0⎥
# ⎢ ⎥
# ⎣0⎦
# ==> "O6" is True.
